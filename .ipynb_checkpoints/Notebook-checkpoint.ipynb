# %%
import os
import pandas as pd
import numpy as np
from surprise import SVD, Dataset, Reader, BaselineOnly, KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy
DATASET_DIR = "dataset"
GAMES_CSV = os.path.join(DATASET_DIR, "games.csv")
USERS_CSV = os.path.join(DATASET_DIR, "users.csv")
RECOMMENDATIONS_CSV = os.path.join(DATASET_DIR, "recommendations.csv")
dataset_size = 100_000

# %%
recs_pd = pd.read_csv(RECOMMENDATIONS_CSV)[:dataset_size]
recs_pd.head()
# Out:
#     app_id  helpful  funny        date  is_recommended  hours  user_id  \
# 0   975370        0      0  2022-12-12            True   36.3    51580
# 1   304390        4      0  2017-02-17           False   11.5     2586
# 2  1085660        2      0  2019-11-17            True  336.5   253880
# 3   703080        0      0  2022-09-23            True   27.4   259432
# 4   526870        0      0  2021-01-10            True    7.9    23869
#
#    review_id
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4

# %%
games_pd = pd.read_csv(GAMES_CSV)
games_pd.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
#    discount  steam_deck
# 0       0.0        True
# 1       0.0        True
# 2       0.0        True
# 3       0.0        True
# 4       0.0        True

# %%
users_pd = pd.read_csv(USERS_CSV)
users_pd.head()
# Out:
#     user_id  products  reviews
# 0   7360263       359        0
# 1  14020781       156        1
# 2   8762579       329        4
# 3   4820647       176        4
# 4   5167327        98        2

# %%
recs_pd["hours"].describe()
# Out:
# count    100000.000000
# mean        200.159673
# std         236.029457
# min           0.000000
# 25%          30.900000
# 50%          99.200000
# 75%         283.200000
# max         999.900000
# Name: hours, dtype: float64

# %%
recs_pd["helpful"].describe()
# Out:
# count    100000.000000
# mean          3.318010
# std          63.122022
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       15219.000000
# Name: helpful, dtype: float64

# %%
recs_pd["rating"] = (recs_pd["is_recommended"].astype(int) * 8
                        + np.log1p(recs_pd["hours"])
                        )

#Normalize rating
recs_pd["rating"] = ((recs_pd["rating"] - recs_pd["rating"].min()) /
                    (recs_pd["rating"].max() - recs_pd["rating"].min()))

# %%
recs_pd["is_recommended"].astype(int).describe()
# Out:
# count    100000.000000
# mean          0.846610
# std           0.360365
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: is_recommended, dtype: float64

# %%
recs_pd["is_recommended"].astype(int).hist(bins=100)
# Out:
# <Axes: >

# %%
recs_pd["rating"].hist(bins=100)
# Out:
# <Axes: >

# %%
recs_df = recs_pd[["user_id", "app_id", "rating"]]
recs_df
# Out:
#         user_id   app_id    rating
# 0         51580   975370  0.777926
# 1          2586   304390  0.164070
# 2        253880  1085660  0.926614
# 3        259432   703080  0.759523
# 4         23869   526870  0.681193
# ...         ...      ...       ...
# 99995   9044739  1361210  0.329249
# 99996  10737213      570  0.977236
# 99997  11674093  1091500  0.844499
# 99998  12306909   582660  0.278112
# 99999  13144699   976730  0.708817
#
# [100000 rows x 3 columns]

# %%
reader = Reader(rating_scale=(0,1))
data = Dataset.load_from_df(recs_df, reader)

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
models = {
    "Baseline": BaselineOnly(),
    "UserKNN": KNNBasic(sim_options={"user_based": True}),
    "ItemKNN": KNNBasic(sim_options={"user_based": False}),
    "SVD": SVD(random_state=42),
}

for name, model in models.items():
    model.fit(train)
    preds = model.test(test)
    print(f'{name}: MSRE: {accuracy.rmse(preds)}, MAE: {accuracy.mae(preds)}' )
    print('\n')
# Out:
# Estimating biases using als...
# RMSE: 0.2215
# MAE:  0.1595
# Baseline: MSRE: 0.2215275988916276, MAE: 0.15946489665801142
#
#
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2329
# MAE:  0.1697
# UserKNN: MSRE: 0.23291684579206545, MAE: 0.16974575796021346
#
#
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.2326
# MAE:  0.1695
# ItemKNN: MSRE: 0.2326062857186894, MAE: 0.16951848576490858
#
#
# RMSE: 0.2217
# MAE:  0.1606
# SVD: MSRE: 0.22173702893844027, MAE: 0.16058365442758046

# %%
def recommend_games(user_id, model, games_df, ratings_df, n=10):
    played_games = set(
        ratings_df[ratings_df["user_id"] == user_id]["app_id"]
    )

    all_games = games_df["app_id"].unique()

    predictions = []
    for game_id in all_games:
        if game_id not in played_games:
            pred = model.predict(user_id, game_id)
            predictions.append((game_id, pred.est))

    predictions.sort(key=lambda x: x[1], reverse=True)
    top_n = predictions[:n]

    result = pd.DataFrame(top_n, columns=["app_id", "predicted_rating"])
    return result.merge(games_df[["app_id", "title"]], on="app_id")

# %%
recommend_games(10, models["Baseline"], games_pd, recs_df)
# Out:
#    app_id  predicted_rating                                          title
# 0  294100          0.886381                                       RimWorld
# 1  105600          0.881104                                       Terraria
# 2    4000          0.876344                                    Garry's Mod
# 3  250900          0.870293                  The Binding of Isaac: Rebirth
# 4  548430          0.863854                             Deep Rock Galactic
# 5  413150          0.859363                                 Stardew Valley
# 6  394360          0.855802                              Hearts of Iron IV
# 7     730          0.849624               Counter-Strike: Global Offensive
# 8  435150          0.841721  Divinity: Original Sin 2 - Definitive Edition
# 9   22380          0.841537                             Fallout: New Vegas

# %%
review_mask = (users_pd["reviews"] > 5) & (users_pd["reviews"] < 11)
subset = users_pd.loc[users_pd.index.isin(recs_df["user_id"]) & review_mask]

users_with_few_recs = subset.head(10)
users_with_few_recs
# Out:
#         user_id  products  reviews
# 534    11440751       409        6
# 1308    3821376       232        6
# 4096   10155759      1345        8
# 4436   10617144       564        7
# 5690   11298505       166        8
# 7210   11620184       205        7
# 13492    699241       205        6
# 16316   3144040       124        6
# 16954   3561071        72        7
# 17897   4128430       426        7

# %%
t = recs_pd['user_id'].isin([7210])
t
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: user_id, Length: 100000, dtype: bool

# %%
recs_pd
# Out:
#         app_id  helpful  funny        date  is_recommended  hours   user_id  \
# 0       975370        0      0  2022-12-12            True   36.3     51580
# 1       304390        4      0  2017-02-17           False   11.5      2586
# 2      1085660        2      0  2019-11-17            True  336.5    253880
# 3       703080        0      0  2022-09-23            True   27.4    259432
# 4       526870        0      0  2021-01-10            True    7.9     23869
# ...        ...      ...    ...         ...             ...    ...       ...
# 99995  1361210        6      0  2022-12-08           False  143.4   9044739
# 99996      570        0      0  2018-02-27            True  713.4  10737213
# 99997  1091500        0      0  2020-12-11            True   99.0  11674093
# 99998   582660        5      2  2022-04-06           False   66.7  12306909
# 99999   976730        0      0  2019-12-17            True   12.4  13144699
#
#        review_id    rating
# 0              0  0.777926
# 1              1  0.164070
# 2              2  0.926614
# 3              3  0.759523
# 4              4  0.681193
# ...          ...       ...
# 99995      99995  0.329249
# 99996      99996  0.977236
# 99997      99997  0.844499
# 99998      99998  0.278112
# 99999      99999  0.708817
#
# [100000 rows x 9 columns]

# %%
target_user_ids = users_with_few_recs["user_id"]
target_user_ids
# Out:
# 534      11440751
# 1308      3821376
# 4096     10155759
# 4436     10617144
# 5690     11298505
# 7210     11620184
# 13492      699241
# 16316     3144040
# 16954     3561071
# 17897     4128430
# Name: user_id, dtype: int64

# %%
positive_reviews = recs_pd[
    (recs_pd['user_id'].isin(target_user_ids)) & 
    (recs_pd['is_recommended'] == True)
]
positive_reviews
# Out:
# Empty DataFrame
# Columns: [app_id, helpful, funny, date, is_recommended, hours, user_id, review_id, rating]
# Index: []

# %%
merged = positive_reviews.merge(games_pd[['app_id', 'title']], on='app_id', how='left')

user_positive_titles = merged.groupby('user_id')['title'].apply(list)

merged.head()
# Out:
# Empty DataFrame
# Columns: [app_id, helpful, funny, date, is_recommended, hours, user_id, review_id, rating, title]
# Index: []
